# %% [markdown]
# # 1. Visualising actions
#
# This week we will work with event data. Here we assume you have watched the [setting up for the course video](https://uppsala.instructure.com/courses/28112/pages/0-getting-started) at the bottom of 'week 0' and have set up an environment where you can program in Python. Please work through this webpage, doing the exercises as you go. It is good if you can work with sections 1.1 - 1.3 before the first lecture on Tuesday 1st September at 10:15.
#
# ## 1.1 Handling Event Data
#
# In this lecture I go through the basics of loading in event data from Statsbomb.
#
# [![Handling Event Data](//www.youtube.com/embed/GTtuOt03FM0)](//www.youtube.com/embed/GTtuOt03FM0)
#
# Learning goals for this video are:
# 1. Downloading code and data
# 2. Organising working folder
# 3. Loading in data in a json file?
# 4. Using ‘for’ loops and ‘if’ statements
# 5. Identifying specific matches in Statsbomb data
#
# The code you need for today's lecture is available in [https://github.com/Friends-of-Tracking-Data-FoTD/SoccermaticsForPython](https://github.com/Friends-of-Tracking-Data-FoTD/SoccermaticsForPython)
#
# ## 1.2 Plotting actions on a pitch
#
# We now look at how to plot actions on a pitch.
#
# [![Plotting actions on a pitch](//www.youtube.com/embed/oOAnERLiN5U)](//www.youtube.com/embed/oOAnERLiN5U)
#
#
#
# Learning goals for this video are:
# 1. Loading match data and finding all the shots
# 2. Plotting shots on the pitch and highlighting goals.
# 3. Plotting expected goals
# 4. Plotting passes
#
# The code you need for today's lecture is available in: [https://github.com/Friends-of-Trackin](https://github.com/Friends-of-Trackin)
#
# ### 1.3 Mini-challenge: plotting actions
#
# 1. Think of a player who you enjoyed watching at the recent Men’s or Women’s World Cups.
# 2. What actions did they perform that were important and why?
# 3. Plot the actions and describe how the data supports or contradicts your own analysis.
# 4. Write a short text using at most two figures that illustrate your point.
#
# Go into the Discussion group for this mini-challenge and post your answers. You are very welcome to use methods discussed in later lectures here. Deadline is the evening of Wednesday 9th, before the tutorial in course week 2.
#
# ### 1.4 Live lecture: insights from data.
#
# This lecture will take place on the 1st of September at 10:15.
#
# [![Insights from data](//www.youtube.com/embed/yX85v-ASzQw)](//www.youtube.com/embed/yX85v-ASzQw)
#
# Lecture note from this lecture can be downloaded [here](https://uppsala.instructure.com/courses/28112/files/1035635/download?wrap=1).
#
# ## 1.5 More advanced visualisations and data analysis
#
#
#
# [![Luca Pappalardo talks us through the Wyscout data set.](//www.youtube.com/embed/ZXEHPKmx410)](//www.youtube.com/embed/ZXEHPKmx410)
#
# In this video he covers:
# 1. The Wyscout data set, how it is collected, from players to events.
# 2. Basic statistics on events and distributions.
# 3. Plotting events on the field, match evolution and spatial stats.
# 4. Advanced statistics: passing networks, flow centrality and playerRank
#
# You should download the code at [https://github.com/Friends-of-Tracking-Data-FoTD/mapping-match-events-in-Python](https://github.com/Friends-of-Tracking-Data-FoTD/mapping-match-events-in-Python) and work through the data set together with the video.
#
# ### 1.6 Guest lecture: good practice in visualisation.
#
# Opta's Peter McKeever gives us insight into how to make better data visualisations. This lecture will take place on the 3rd of September at 15:15.
#
# [[Good practice in visualisation](//www.youtube.com/embed/md0pdsWtq_o)](//www.youtube.com/embed/md0pdsWtq_o)
#
# Peter's notes are [here](https://uppsala.instructure.com/courses/28112/files/1042670/download?wrap=1). Peter has an excellent blog with code and further [examples](http://petermckeever.com/blog/). He also mentioned the blog by [Lisa Charlotte Rost](https://lisacharlotterost.de/).
#
# **Time progress**: You should have watched this material by Friday 4th September and posted your analysis of World Cup data by Wednesday 9th.
