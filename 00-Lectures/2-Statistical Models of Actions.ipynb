# %% [markdown]
# # 2. Statistical Models of Actions
#
# ## 2.1 Introducing expected goals
#
# An introduction and discussion of expected goals. Here are three videos: one by me, one by Duncan Alexander at Opta, and one by Tifo football.
#
# - [Introducing expected goals by the course instructor](//www.youtube.com/embed/Xc6IG9-Dt18)
# - [Expected goals discussion by Duncan Alexander](//www.youtube.com/embed/w7zPZsLGK18)
# - [Tifo football's take on expected goals](//www.youtube.com/embed/zSaeaFcm1SY)
#
# By now, you should have got the idea!
#
# ## 2.2 Statistical models in football
#
# Tuesday's lecture 10:15 -12:00 will cover statistical models for pass heat maps, possession, and develop the idea of expected goals.
#
# [Statistical models in football](//www.youtube.com/embed/JW2QVXTnlbQ)
#
# Notes from this lecture are available [here](https://uppsala.instructure.com/api/v1/canvadoc_session?blob=%7B%22moderated_grading_whitelist%22:null,%22enable_annotations%22:null,%22enrollment_type%22:null,%22anonymous_instructor_annotations%22:null,%22submission_id%22:null,%22user_id%22:145890000000003804,%22attachment_id%22:1053795,%22type%22:%22canvadoc%22%7D&amp;hmac=3b16e2b758b0ff085047a05ebbad989c76a28737).
#
# The code for this lecture can be found [here](https://github.com/Friends-of-Tracking-Data-FoTD/SoccermaticsForPython).
#
# ## 2.3 The data used
#
# [This lecture goes step by step through the data needed to create an expected goals model](//www.youtube.com/embed/bpjLyFyLlXs).
#
# - Why Expected Goals are Important
# - Plotting 2D histogram of shot and goal positions
# - How probability of scoring depends on shot angle and distance
#
# The code for this lecture can be found [here](https://github.com/Friends-of-Tracking-Data-FoTD/SoccermaticsForPython).
#
# ## 2.4 Fitting the model
#
# The video covers:
# 1. Fitting straight lines using linear regression
# 2. The logistic function
# 3. Fitting shot angle and distance separately
# 4. Working with regression tools
#
# [Fitting the model](//www.youtube.com/embed/wHOgINJ5g54)
#
# Specifically, the lectures cover `4LinearRegression.py` and `5xGModelFit.py`. The code can be found [here](https://github.com/Friends-of-Tracking-Data-FoTD/SoccermaticsForPython).
#
# ## 2.5 Using expected goals in practice
#
# [VIDEO: Using expected goals in practice](//www.youtube.com/embed/310_eW0hUqQ)
#
#
# References include articles and discussions on the importance and application of expected goals in football analysis.
#
# - Anatomy of a Goal - Numberphile: https://www.youtube.com/watch?v=YJuHC7xXsGA
# - The Geometry of Shooting: https://soccermatics.medium.com/the-geometry-of-shooting-ae7a67fdf760).
#
# - Caley: https://cartilagefreecaptain.sbnation.com/2013/11/13/5098186/shot-matrix-i-shot-location-and-expected-goals
#
# - Twelve xG: https://analytics.twelve.football/analytics
#
# - Tracking data xG: https://twitter.com/jernejfl/status/1258299564878106624?s=20
#
# - Big chance: https://soccermatics.medium.com/footballs-magical-equation-bfe212ce7d4a
#
# - When to use xG: https://soccermatics.medium.com/should-you-write-about-real-goals-or-expected-goals-a-guide-for-journalists-2cf0c7ec6bb6
#
# - Review of value models: https://www.americansocceranalysis.com/home/2020/5/5/goals-added-and-the-great-possession-shift
# -
# Michael Caley on expected goals: https://cartilagefreecaptain.sbnation.com/2014/2/28/5452786/shot-matrix-tottenham-hotspur-stats-analysis-expected-goals
#
# Trigonometry of shot angle: Morales, César A. "A mathematics-based new penalty area in football: tackling diving." Journal of sports sciences 34, no. 24 (2016): 2233-2237.
#
# ## 2.6 Pass success predictor
#
# This is a graded exercise on evaluating pass quality. The deadline is Sunday 20th of September. We will discuss this in the tutorials on the 10th and 17th of September. [Evaluating passes](https://uppsala.instructure.com/courses/28112/assignments/29463) for details.
